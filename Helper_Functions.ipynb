# %% [markdown]
# #### __Imports__

# %%
from collections import Counter

import pandas as pd  # for easy and effective catalogue manipulation
import numpy as np  # for mathematic stuff

from ipywidgets import widgets  # for easy implement UI directly in notebook

import plotly.graph_objs as go
import plotly.io as pio
from plotly.offline import init_notebook_mode, iplot  # for beautifull plot

pio.renderers.default = "colab"

import cufflinks as cf  # to directly bind pandas and plotly

import requests  # for dealing with API
import json  # to deal with json inputs/outputs
import pprint  # for more friendly console formatting
import operator  # often faster than lambda expression

import sklearn.metrics.pairwise as skdist
import statistics

cf.go_offline()  # set plotly to offline mode
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #### __Download and rename datasets (catalogue and user data)__

# %%
! rm x5gon_catelogue.tsv*
! rm x5gon_user_data.psv*
! mkdir datasets
! wget https://gitlab.univ-nantes.fr/x5gon/x5gon-hackathon-datasets/raw/master/datasets/x5gon_catelogue.tsv
! wget https://gitlab.univ-nantes.fr/x5gon/x5gon-hackathon-datasets/raw/master/datasets/x5gon_user_data.psv
! mv x5gon_catelogue.tsv datasets/catalogue.tsv
! mv x5gon_user_data.psv datasets/user_data.psv
# Out:
# rm: cannot remove 'x5gon_catelogue.tsv*': No such file or directory
# rm: cannot remove 'x5gon_user_data.psv*': No such file or directory
# mkdir: cannot create directory ‘datasets’: File exists
# --2020-02-25 11:07:37--  https://gitlab.univ-nantes.fr/x5gon/x5gon-hackathon-datasets/raw/master/datasets/x5gon_catelogue.tsv
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving gitlab.univ-nantes.fr (gitlab.univ-nantes.fr)... 193.52.101.66
# Connecting to gitlab.univ-nantes.fr (gitlab.univ-nantes.fr)|193.52.101.66|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63850145 (61M) [text/plain]
# Saving to: ‘x5gon_catelogue.tsv’
#
# x5gon_catelogue.tsv 100%[===================>]  60.89M  19.0MB/s    in 3.2s
#
# 2020-02-25 11:07:42 (19.0 MB/s) - ‘x5gon_catelogue.tsv’ saved [63850145/63850145]
#
# --2020-02-25 11:07:42--  https://gitlab.univ-nantes.fr/x5gon/x5gon-hackathon-datasets/raw/master/datasets/x5gon_user_data.psv
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving gitlab.univ-nantes.fr (gitlab.univ-nantes.fr)... 193.52.101.66
# Connecting to gitlab.univ-nantes.fr (gitlab.univ-nantes.fr)|193.52.101.66|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 255593745 (244M) [text/plain]
# Saving to: ‘x5gon_user_data.psv’
#
# x5gon_user_data.psv 100%[===================>] 243.75M  17.1MB/s    in 20s
#
# 2020-02-25 11:08:05 (12.1 MB/s) - ‘x5gon_user_data.psv’ saved [255593745/255593745]

# %% [markdown]
# #### __Preview catalogue__

# %%
list_parser = lambda x: x[1:-1].split(",")
catalogue = pd.read_csv(
    "datasets/catalogue.tsv",
    sep="\t",
    converters={"keywords": list_parser, "concepts": list_parser},
)
# This is added in case initial dataset hasn't the right columns names:
catalogue.columns = ["id", "title", "language", "type", "keywords", "concepts"]
catalogue.set_index("id", inplace=True)
catalogue.head(20)
# Out:
#                                                    title language type  \
# id
# 59260                          C7 - Computing with Space       en  pdf
# 3904          Electromagnetic Fields, Forces, and Motion       en  pdf
# 4796                                    Uncertain Allies       en  pdf
# 5757          Statistics for Brain and Cognitive Science       en  pdf
# 6930   Classification of Web Documents Using a Graph-...       en  mp4
# 8160          Advanced Fluid Dynamics of the Environment       en  pdf
# 11812  Lecture 5 - Work-Energy Theorem and Law of Con...       en  mov
# 23191                           Medical Decision Support       en  pdf
# 40540  Distinguishing Causes from Effects using Nonli...       fr  mp4
# 43621                                  Computer Graphics       en  pdf
# 48869                           Microeconomic Theory III       en  pdf
# 51007  Designing and Sustaining Technology Innovation...       en  pdf
# 53259                                    New Enterprises       en  pdf
# 57981                   Mathematics for Computer Science       en  pdf
# 37227                   String Theory for Undergraduates       en  pdf
# 69377  An Introduction to Intelligent Transportation ...       en  pdf
# 70407  Optimizing Multi-Class Spatio-Spectral Filters...       en  pdf
# 79827  Approaches of Systems Biology of Metabolically...       en  pdf
# 80431  Nonlinear Mappings for Generative Kernels on L...       en  pdf
# 86736  IntroducciÃ³n a la plataforma para mÃ³viles An...       es  mp4
#
#                                                 keywords  \
# id
# 59260  [space,  omicini,  c7,  omicini disi,  disi un...
# 3904   [forces motion,  fields forces,  electromagnet...
# 4796   [north korea,  korea,  china,  north,  pyongya...
# 5757   [pr,  pr pr,  probability,  probability theory...
# 6930   [graph,  subgraph,  document,  contrast,  clas...
# 8160   [fluid,  mei,  layer,  temperature,  water sur...
# 11812  [force,  velocity,  minus,  energy,  function,...
# 23191  [clinical,  database,  db,  risk,  report,  la...
# 40540  [causal,  nonlinear,  model,  ica,  disturbanc...
# 43621  [ray,  dir,  intersection,  y1,  y2,  traverse...
# 48869  [ann,  asset,  utility,  problem,  iii,  grade...
# 51007  [jeff,  health,  clinical,  harvard,  technolo...
# 53259  [new enterprises,  enterprises,  team,  founde...
# 57981  [proposition,  true,  mcs ftl,  ftl page,  ftl...
# 37227  [point problem,  string,  problem point,  cyli...
# 69377  [transportation,  joseph sussman,  sussman,  i...
# 70407  [eeg,  experiments conclusions,  conclusions, ...
# 79827  [ho,  metabolic,  et al,  pk,  al,  et,  ho ho...
# 80431  [generative,  kernel,  hmm,  normalization,  n...
# 86736  [android,  mobile,  tap,  platform,  year,  vi...
#
#                                                 concepts
# id
# 59260  ['http://en.wikipedia.org/wiki/Bologna',  'htt...
# 3904   ['http://en.wikipedia.org/wiki/Massachusetts_I...
# 4796   ['http://en.wikipedia.org/wiki/North_Korea',  ...
# 5757   ['http://en.wikipedia.org/wiki/Probability_the...
# 6930   ['http://en.wikipedia.org/wiki/Hello',  'http:...
# 8160   ['http://en.wikipedia.org/wiki/Homework',  'ht...
# 11812  ['http://en.wikipedia.org/wiki/Conservation_of...
# 23191  ['http://en.wikipedia.org/wiki/P-value',  'htt...
# 40540  ['http://en.wikipedia.org/wiki/Nonlinear_syste...
# 43621  ['http://en.wikipedia.org/wiki/K-d_tree',  'ht...
# 48869  ['http://en.wikipedia.org/wiki/Microeconomics'...
# 51007  ['http://en.wikipedia.org/wiki/Massachusetts_I...
# 53259  ['http://en.wikipedia.org/wiki/Business',  'ht...
# 57981  ['http://en.wikipedia.org/wiki/Truth_table',  ...
# 37227  ['http://en.wikipedia.org/wiki/Homework',  'ht...
# 69377  ['http://en.wikipedia.org/wiki/Antonov',  'htt...
# 70407  ['http://en.wikipedia.org/wiki/Electroencephal...
# 79827  ['http://en.wikipedia.org/wiki/Carotenoid',  '...
# 80431  ['http://en.wikipedia.org/wiki/Nonlinear_syste...
# 86736  ['http://en.wikipedia.org/wiki/Machine_learnin...

# %% [markdown]
# #### __Preview users__

# %%
list_parser = lambda x: x[1:-1].split("|")
users = pd.read_csv(
    "datasets/user_data.psv",
    sep="|",
    converters={"keywords": list_parser, "concepts": list_parser},
)
# This is added in case initial dataset hasn't the right columns names:
users.columns = ["id", "url", "timestamp"]
users.set_index("timestamp", inplace=True)
users.head(20)
# Out:
#                             id     url
# timestamp
# 2020-02-05 16:54:55.407645   0   85079
# 2020-02-05 21:29:13.219211   0   85079
# 2020-02-05 16:54:55.410975   1  141207
# 2020-02-06 14:45:36.547601   1  141207
# 2020-02-07 00:49:01.311032   1  141207
# 2020-02-08 17:54:43.255974   1  141207
# 2020-02-05 16:54:55.414236   2   85880
# 2020-02-05 17:29:13.414236   2   83438
# 2020-02-05 17:29:43.414236   2   83438
# 2020-02-05 16:54:55.417606   3    2099
# 2020-02-06 07:00:18.417606   3   14495
# 2020-02-06 07:17:35.417606   3    2099
# 2020-02-06 07:29:41.417606   3    2099
# 2020-02-07 11:14:16.695300   3    2099
# 2020-02-11 06:07:38.873074   3    2099
# 2020-02-11 10:17:15.424700   3    2099
# 2020-02-11 11:57:57.760750   3    2099
# 2020-02-12 13:56:19.108033   3    2099
# 2020-02-05 16:54:55.420881   4   41467
# 2020-02-05 18:23:20.739967   4   41467

# %% [markdown]
# #### __Search query example__

# %%
# The X5GON API is available at:
PLATFORM_URL = "https://platform.x5gon.org/api/v1/"
function = "search/"
parameter = "text="
keyword = "perceptron"
response = requests.get(PLATFORM_URL + function + "?" + parameter + keyword)
r_json = response.json()

# store query results in a dict of dicts {material_d: {material_data}}
# also remove duplicates by comparing material descriptions
materials = {}
for result in r_json["rec_materials"]:
    materials[result["material_id"]] = result
    materials[result["material_id"]].pop("material_id", None)

df_materials = pd.DataFrame(materials)
df_materials = df_materials.T
df_materials
# Out:
#          weight                                              title  \
# 66731   31.1591                         The Multi-layer Perceptron
# 65029   30.1091  The Projectron: a Bounded Kernel-Based Perceptron
# 137065  30.0063  Fast learning of Document Ranking Functions wi...
# 11997   29.0144  The Projectron: a Bounded Kernel-Based Perceptron
# 8542    28.1756                         The Multi-layer Perceptron
# 8343    27.6245  Fast learning of Document Ranking Functions wi...
# 79325   22.8812  Surrogate Functions for Maximizing Precision a...
# 72072   22.7092   On-line learning algorithms: theory and practice
# 69429   22.6157  Online Similarity Prediction of Networked Data...
# 71650   22.6097                       On-line Statistical Learning
# 37091    22.592       Statistical Learning Theory and Applications
# 72947   22.5189          Algorithms for Predicting Structured Data
# 73088   22.5063  Exploiting feature covariance in high-dimensio...
# 13063   22.4973               Advanced Natural Language Processing
# 79155   22.4849  Efficient Bandit Algorithms for Online Multicl...
# 44874   22.4532                                   Machine Learning
# 42647   22.4532                            Artificial Intelligence
# 63767   22.4115       Learning Prediction Suffix Trees with Winnow
# 39212   22.3919                    Introduction to Neural Networks
# 64079    22.313                                   Machine Learning
#
#                                               description  \
# 66731   This presentation describes the multilayer per...
# 65029   We present a discriminative online algorithm w...
# 137065
# 11997   We present a discriminative online algorithm w...
# 8542    This presentation describes the multilayer per...
# 8343                                                 None
# 79325   The problem of maximizing precision at the top...
# 72072                                                None
# 69429   We consider online similarity prediction probl...
# 71650                                                None
# 37091   This course is for upper-level graduate studen...
# 72947   Structured prediction is the problem of predic...
# 73088   Some online algorithms for linear classificati...
# 13063   This course is a graduate introduction to natu...
# 79155   This paper introduces the Banditron, a variant...
# 44874   6.867 is an introductory course on machine lea...
# 42647   This course introduces students to the basic k...
# 63767   Prediction suffix trees (PSTs) are a popular t...
# 39212   This course explores the organization of synap...
# 64079   6.867 is an introductory course on machine lea...
#
#                    creation_date            retrieved_date   type  \
# 66731   2008-01-21T10:26:07.000Z  2018-08-02T11:32:58.041Z   text
# 65029   2008-07-08T11:30:00.000Z  2018-08-02T11:44:18.703Z   text
# 137065  2008-02-11T13:45:00.000Z  2019-10-29T10:41:13.248Z   text
# 11997   2008-07-08T11:30:00.000Z  2018-08-02T11:44:18.703Z  video
# 8542    2008-01-21T10:26:07.000Z  2018-08-02T11:32:58.041Z  video
# 8343    2008-02-11T13:45:00.000Z  2018-08-02T12:52:08.217Z  video
# 79325   2015-07-08T13:44:45.000Z  2018-08-02T11:45:56.622Z   text
# 72072   2007-10-24T09:00:00.000Z  2020-01-13T13:40:23.592Z   text
# 69429   2013-06-13T15:00:00.000Z  2020-01-14T22:16:48.739Z   text
# 71650   2007-01-31T00:00:00.000Z  2020-01-16T02:37:22.089Z   text
# 37091                       None  2018-06-14T15:04:27.000Z   text
# 72947   2010-09-20T14:00:00.000Z  2018-08-02T11:30:00.034Z   text
# 73088   2010-05-14T18:43:00.000Z  2018-08-02T11:14:36.445Z   text
# 13063                       None  2018-06-14T13:55:30.000Z   text
# 79155   2008-07-08T11:55:00.000Z  2020-01-14T14:26:48.759Z   text
# 44874                       None  2018-06-14T13:23:01.000Z   text
# 42647                       None  2018-06-14T15:26:50.000Z   text
# 63767   2009-06-15T11:45:00.000Z  2018-08-02T11:44:44.694Z   text
# 39212                       None  2018-06-14T15:13:37.000Z   text
# 64079                       None  2018-06-14T13:23:01.000Z   text
#
#                mimetype                                                url  \
# 66731   application/pdf  http://hydro.ijs.si/v002/8c/rqh3wjwyfcx4j4mayz...
# 65029   application/pdf  http://hydro.ijs.si/v002/4e/jzcm5wc7mniw2xc4ct...
# 137065  application/pdf  http://hydro.ijs.si/v002/40/iahak5ao5zin3gmtpx...
# 11997         video/mp4  http://hydro.ijs.si/v002/d0/2ci2ggjinmnmra4g3j...
# 8542          video/mp4  http://hydro.ijs.si/v002/0d/bxku65bxlnzaudo3ux...
# 8343          video/mp4  http://hydro.ijs.si/v002/4e/jyygewqam7awndgsph...
# 79325   application/pdf  http://hydro.ijs.si/v012/4b/jnajx6667vfgohvwaz...
# 72072   application/pdf  http://hydro.ijs.si/v001/2b/fmyf4tqf6hu3rpokyu...
# 69429   application/pdf  http://hydro.ijs.si/v00d/38/hckovwpuc6i5subzwu...
# 71650   application/pdf  http://hydro.ijs.si/v001/13/cnjeui6xgpsje3gkcs...
# 37091   application/pdf  https://ocw.mit.edu/courses/brain-and-cognitiv...
# 72947   application/pdf  http://hydro.ijs.si/v009/12/ck3743qxhusvzv7flx...
# 73088   application/pdf  http://hydro.ijs.si/v008/e1/4gmkkwhoavkp2chd3p...
# 13063   application/pdf  https://ocw.mit.edu/courses/electrical-enginee...
# 79155   application/pdf  http://hydro.ijs.si/v002/bd/xxvcnw7uwtbedrfs6y...
# 44874   application/pdf  https://ocw.mit.edu/courses/electrical-enginee...
# 42647   application/pdf  https://ocw.mit.edu/courses/electrical-enginee...
# 63767   application/pdf  http://hydro.ijs.si/v005/1c/dqoe3innucx6hcmosj...
# 39212   application/pdf  https://ocw.mit.edu/courses/brain-and-cognitiv...
# 64079   application/pdf  https://ocw.mit.edu/courses/electrical-enginee...
#
#                                                   website language  \
# 66731     http://videolectures.net/epsrcws08_harison_tmp/       en
# 65029        http://videolectures.net/icml08_orabona_pbk/       en
# 137065        http://videolectures.net/wsdm08_elsas_fldr/       en
# 11997        http://videolectures.net/icml08_orabona_pbk/       en
# 8542      http://videolectures.net/epsrcws08_harison_tmp/       en
# 8343          http://videolectures.net/wsdm08_elsas_fldr/       en
# 79325   http://videolectures.net/icml2015_kar_surrogat...       en
# 72072    http://videolectures.net/aop07_cesa_bianchi_onl/       en
# 69429   http://videolectures.net/colt2013_herbster_gra...       en
# 71650         http://videolectures.net/stw07_bianchi_lsl/       en
# 37091   https://ocw.mit.edu/courses/brain-and-cognitiv...       en
# 72947   http://videolectures.net/ecmlpkdd2010_gartner_...       en
# 73088      http://videolectures.net/aistats2010_ma_efcih/       en
# 13063   https://ocw.mit.edu/courses/electrical-enginee...       en
# 79155        http://videolectures.net/icml08_shwartz_eba/       en
# 44874   https://ocw.mit.edu/courses/electrical-enginee...       en
# 42647   https://ocw.mit.edu/courses/electrical-enginee...       en
# 63767   http://videolectures.net/icml09_karampatziakis...       en
# 39212   https://ocw.mit.edu/courses/brain-and-cognitiv...       en
# 64079   https://ocw.mit.edu/courses/electrical-enginee...       en
#
#                                                   license  \
# 66731   {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 65029   {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 137065  {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 11997   {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 8542    {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 8343    {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 79325   {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 72072   {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 69429   {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 71650   {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 37091   {'short_name': 'X5GON recommends the use of th...
# 72947   {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 73088   {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 13063   {'short_name': 'X5GON recommends the use of th...
# 79155   {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 44874   {'short_name': 'X5GON recommends the use of th...
# 42647   {'short_name': 'X5GON recommends the use of th...
# 63767   {'short_name': 'by-nc-nd', 'typed_name': ['by'...
# 39212   {'short_name': 'X5GON recommends the use of th...
# 64079   {'short_name': 'X5GON recommends the use of th...
#
#                                                  provider  \
# 66731   {'id': 1, 'name': 'videolectures.net', 'domain...
# 65029   {'id': 1, 'name': 'videolectures.net', 'domain...
# 137065  {'id': 1, 'name': 'videolectures.net', 'domain...
# 11997   {'id': 1, 'name': 'videolectures.net', 'domain...
# 8542    {'id': 1, 'name': 'videolectures.net', 'domain...
# 8343    {'id': 1, 'name': 'videolectures.net', 'domain...
# 79325   {'id': 1, 'name': 'videolectures.net', 'domain...
# 72072   {'id': 1, 'name': 'videolectures.net', 'domain...
# 69429   {'id': 1, 'name': 'videolectures.net', 'domain...
# 71650   {'id': 1, 'name': 'videolectures.net', 'domain...
# 37091   {'id': 10, 'name': 'mit opencourseware', 'doma...
# 72947   {'id': 1, 'name': 'videolectures.net', 'domain...
# 73088   {'id': 1, 'name': 'videolectures.net', 'domain...
# 13063   {'id': 10, 'name': 'mit opencourseware', 'doma...
# 79155   {'id': 1, 'name': 'videolectures.net', 'domain...
# 44874   {'id': 10, 'name': 'mit opencourseware', 'doma...
# 42647   {'id': 10, 'name': 'mit opencourseware', 'doma...
# 63767   {'id': 1, 'name': 'videolectures.net', 'domain...
# 39212   {'id': 10, 'name': 'mit opencourseware', 'doma...
# 64079   {'id': 10, 'name': 'mit opencourseware', 'doma...
#
#                                               content_ids
# 66731                                            [173471]
# 65029                                            [171743]
# 137065                                           [278370]
# 11997   [28053, 28054, 28055, 28056, 28057, 28058, 280...
# 8542    [19374, 19375, 267102, 19376, 19377, 267103, 1...
# 8343    [18791, 18792, 18793, 18794, 18795, 18796, 187...
# 79325                                            [183869]
# 72072   [308921, 308917, 308922, 308915, 308918, 30891...
# 69429   [316761, 316757, 316762, 316755, 316758, 31675...
# 71650   [327282, 327278, 327283, 327276, 327279, 32728...
# 37091                                            [145565]
# 72947                                            [179917]
# 73088                                            [180048]
# 13063                                            [195202]
# 79155   [314217, 314213, 314218, 314211, 314214, 31421...
# 44874                                            [151816]
# 42647                                            [149649]
# 63767                                            [170510]
# 39212                                            [147103]
# 64079                                            [170802]

# %% [markdown]
# #### __Given a keyword search display users that accessed this content__

# %%
for key in df_materials.index:
    res = users[users.url == key].id
    if not res.empty:
        print(f"The material {key} - {materials[key]['title']} was accessed by:")
        print(users[users.url == key].id.values)
        print("")
# Out:
# The material 137065 - Fast learning of Document Ranking Functions with the Committee Perceptron was accessed by:
# [ 23716  29126  29860  33138  40477  45497  58124  58443  59595  70982
#   71626  71844  75332  76401  76617  79497  81867 109506 110838 113939
#  525080 525080 525080 525080 525080 525080 525080 525080 531958 531958
#  531958 531958 531958 531958 531958 534999 534999 534999 534999 534999
#  534999 561930 561930 572762 572762 572762 572762 572762 574691 574691
#  574691 579305 579305 579305 583330 583330 583608 583608 583608 583608
#  583608 584920 584920 584920 591792 591792 591792 598938 598938 598938
#  598938 606465 606465 608488 608488 608488 608488 609802 609802 609802
#  609802 609802 626264 626264 626264 626264 626264 630865 630865 645720
#  645720 667374 667374 667374 667811 667811 667811 667811 667811 667811
#  667811 667811 667811 672697 672697 672697 672697 672697 672697 672697
#  672697 672697 672697 672697 672697 672697 675041 675041 680057 680057
#  691699 691699 691699 691699 691699 691699 691699 699591 699591 721391
#  721391 721391 728615 728615 733187 733187 733187 733187 733187 739394
#  739394 747977 747977 759899 759899 764244 764244 764244 764244 764244
#  764244 773878 773878 789400 789400 789400 811509 811509 811509 811509
#  811509 834795 834795 834795 834795 834795 848605 848605 848605 848605
#  848605 852930 852930 855968 855968 857378 857378 860171 860171 860171
#  860171 864412 864412 864412 864412 864412 864412 864412 864412 864412
#  864412 864412 865879 865879 865879 865879 865879 866026 866026 866026
#  878376 878376 878376 878376 878376 878786 878786 879839 879839 879839
#  879839 879839 884673 884673 890938 890938 895802 895802 895802 895802
#  895802 898568 898568 898568 924464 924464 940784 940784 940784 940784
#  940784 940784 940784 953887 953887 956933 956933 956933 956933 956933
#  956933 956933 956933 965226 965226 965226 966898 966898 966898 966898
#  967059 967059 971873 971873 971873 971873 971873 971873 997741 997741]
#
# The material 72947 - Algorithms for Predicting Structured Data was accessed by:
# [  4240  23875  27714  36282  39523  44649  63311  63860  67304  76172
#   77140  85704  88452  93785 100301 101513 101685 106792 108808 112013
#  112222 113132 113549 120114 126637 128413 142974 143364 145002 148954
#  152054 152471 161167 161582 162357 162857 178218 182415 182616 204381
#  205273 207030 213178 213975 218066 226927 238932 242695 259451 261820
#  262654 265577 278948 280233 290931 299101 328336 330527 335537 339850
#  345836 359896 361244 366658 372369 372908 375185 375989 380503 386005
#  393681 397216 405279 429549 429910 440738 451550 452951 466837 486903
#  492304 495633 502693 525339 527582 528984 534170 541363 550347 550806
#  561312 563990 599083 603947 627237 633080 637535 642731 653308 666759
#  669298 673309 682238 713281 717053 718388 732463 738067 750003 774061
#  787040 796777 797850 802253 808873 812229 826995 851551 863537 870189
#  877106 880840 881236 881766 892663 894278 901990 905757 907615 916031
#  916821 937655 944729 948710 955570 961971 983534 994946 997779]

# %% [markdown]
# #### __Save the list of the content accessed, ordered by from access count__

# %%
count = []
for key in catalogue.index:
    res = users[users.url == key].index
    if not res.empty:
        count.append((len(res), catalogue[catalogue.index == key].title))

accessed = []
for c in count:
    accessed.append([c[0], c[1].keys()[0], c[1].values[0]])

test = pd.Series(accessed)
test = test.sort_values()
viewed = pd.DataFrame([[a[0], a[1], a[2]] for a in test])
viewed.to_csv("accessed.tsv", sep="\t", encoding="utf-8", index=False)
